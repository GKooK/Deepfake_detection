# %%
# !pip install tensorflowjs
# Out:
# ...
#      |████████████████████████████████| 77 kB 2.8 MB/s
# ...
#      |████████████████████████████████| 462 kB 8.6 MB/s
# ...

# %%
# !tensorflowjs_converter --input_format=keras ./seventh_try_withaihub_maybe_best_after_3.h5 ./tmp/tfjs_model
