# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import Sequence
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten, Dropout, LSTM, Reshape
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

# %%
import tensorflow as tf
import keras.applications as keras_application

# %%
from keras import backend as K
def recall(y_target, y_pred):
    # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
    # round : 반올림한다
    y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다

    # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 

    # (True Positive + False Negative) = 실제 값이 1(Positive) 전체
    count_true_positive_false_negative = K.sum(y_target_yn)

    # Recall =  (True Positive) / (True Positive + False Negative)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    recall = count_true_positive / (count_true_positive_false_negative + K.epsilon())

    # return a single tensor value
    return recall

def precision(y_target, y_pred):
    # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
    # round : 반올림한다
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다
    y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다

    # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 

    # (True Positive + False Positive) = 예측 값이 1(Positive) 전체
    count_true_positive_false_positive = K.sum(y_pred_yn)

    # Precision = (True Positive) / (True Positive + False Positive)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    precision = count_true_positive / (count_true_positive_false_positive + K.epsilon())

    # return a single tensor value
    return precision

def f1score(y_target, y_pred):
    _recall = recall(y_target, y_pred)
    _precision = precision(y_target, y_pred)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    _f1score = ( 2 * _recall * _precision) / (_recall + _precision+ K.epsilon())
    
    # return a single tensor value
    return _f1score

# %%
from keras.applications import mobilenet_v2

# %%
img_row,img_col=224,224
temp_mobile = mobilenet_v2.MobileNetV2(weights='imagenet', include_top=False, input_shape=(32,img_row*img_col,3), pooling='max')
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
#temp_mobile.summary()

# %%
model=Sequential()

# %%
model.add(temp_mobile)

# %%
model.add(Dense(80, input_shape=(1280,)))

# %%
model.add(Dense(5, input_shape=(80,)))

# %%
model.add(Dropout(rate=0.5))

# %%
model.add(Dense(2, activation='sigmoid'))

# %%
model.compile(loss=tf.keras.losses.BinaryCrossentropy(), optimizer=Adam(learning_rate=0.01), metrics=['acc', recall, precision, f1score])
#lr 스케줄링은 나중에model.fit의 callback안에 넣어주자.
#아래와 같이하면됨
#reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
#                              patience=5, min_lr=0.001)
#model.fit(X_train, Y_train, callbacks=[reduce_lr])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 1280)             2257984
#  ional)
#
#  dense (Dense)               (None, 80)                102480
#
#  dense_1 (Dense)             (None, 5)                 405
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 2,360,881
# Trainable params: 2,326,769
# Non-trainable params: 34,112
# _________________________________________________________________

# %%
#model.save('temp_ml5.h5')

# %%
#sample_data
#test = tf.random.uniform([16,32,224*224,3],0,1)
#배치 크기 16쓰자

# %%
import os
cur_path = os.getcwd()
cur_path+='/drive/Shareddrives/capstone_data_process/temp'
video_src = cur_path+'/celeb-df_v2/pre_process/mixed'

# %%
import os
import cv2
cur_path = os.getcwd()
cur_path+='/drive/Shareddrives/capstone_data_process/temp'
all_data = pd.read_csv((cur_path+'/celeb-df_v2/video_data.csv'), names=['file_name', 'label'])
real_num = len(all_data[all_data['label'] == 1])
fake_num = len(all_data[all_data['label'] == 0])
print(real_num, fake_num , real_num+fake_num)
real_alls = all_data[all_data['label'] == 1]
fake_sample = all_data[all_data['label'] == 0].sample(frac=0.11)
all_data_subset = pd.concat([real_alls, fake_sample])
display(all_data_subset)
data_train, data_test = train_test_split(all_data_subset, test_size = 0.2, random_state=2022)
data_train, data_validation = train_test_split(data_train, test_size=0.25, random_state=2022)
print(len(data_train), len(data_validation), len(data_test))
# Out:
# 566 5349 5915
#                file_name  label
# 0           id0_0000.avi      1
# 1           id0_0001.avi      1
# 2           id0_0002.avi      1
# 3           id0_0003.avi      1
# 4           id0_0004.avi      1
# ...                  ...    ...
# 1316  id52_id53_0009.avi      0
# 4738  id21_id34_0007.avi      0
# 1706  id28_id23_0000.avi      0
# 1475  id53_id57_0004.avi      0
# 4733  id20_id33_0008.avi      0
#
# [1154 rows x 2 columns]
# 692 231 231

# %%
test_load = data_train.sample(n=16, replace=True)

# %%
for i in test_load['file_name']:
  print(i)
# Out:
# id34_id38_0002.avi
# id40_id46_0005.avi
# id8_0000.avi
# id4_id23_0004.avi
# id49_0009.avi
# id19_id27_0001.avi
# id49_id57_0000.avi
# id20_id9_0009.avi
# id45_0007.avi
# id6_id2_0003.avi
# id6_id2_0002.avi
# id43_id39_0006.avi
# id55_id58_0009.avi
# id21_0004.avi
# id2_id30_0004.avi
# id20_id3_0006.avi

# %%
#test_video = cv2.VideoCapture(video_src+'/id32_id30_0000.avi')
#result_list = 0
#for i in range(0, 32):
#  if(type(result_list)==type(0)):
#    read_val = cv2.resize(test_video.read()[1], (224, 224))
#    read_val = read_val/255
#    result_list = read_val.reshape(1,224,224,3)
#  else:
#    read_val = cv2.resize(test_video.read()[1], (224, 224))
#    read_val = read_val/255
#    read_val = read_val.reshape(1,224,224,3)
#    result_list = np.concatenate([result_list, read_val])
#result_list=result_list.reshape(32,-1,3)

# %%
#result_list.shape

# %%
#test_load = data_train.sample(n=16, replace=True)
#return_data = 0
#for i in test_load['file_name']:
#  #영상 가져오기
#  test_video = cv2.VideoCapture(video_src+'/'+i)
#  result_list = 0
#  for i in range(0, 32):
#    if(type(result_list)==type(0)):
#      read_val = cv2.resize(test_video.read()[1], (224, 224))
#      read_val = read_val/255
#      result_list = read_val.reshape(1,224,224,3)
#    else:
#      read_val = cv2.resize(test_video.read()[1], (224, 224))
#      read_val = read_val/255
#      read_val = read_val.reshape(1,224,224,3)
#      result_list = np.concatenate([result_list, read_val])
#  result_list=result_list.reshape(32,-1,3)
#  #영상 가져오기 끝
#  if(type(return_data)==type(0)):
#    return_data = result_list.reshape(1, 32, -1, 3)
#  else:
#    return_data = np.concatenate([return_data, result_list.reshape(1, 32, -1, 3)])
#return_label = []
#for i in test_load['label']:
#  if(i==0):
#    target = np.array([1,0])
#  else:
#    target = np.array([0,1])
#  return_label.append(target)
#return_label = np.stack(return_label)

# %%
#return_label

# %%
#return_data.shape

# %%
#len(data_train)

# %%
class DataGenerator(Sequence):
    def __init__(self, dataset, batch_size):
      self.dataset = dataset
      self.batch_size = batch_size

    def __len__(self):
      return int(len(data_train) / self.batch_size)

    def __getitem__(self, index):
      test_load = self.dataset.sample(n=self.batch_size, replace=True, random_state=index)
      return_data = 0
      for i in test_load['file_name']:
        #영상 가져오기
        test_video = cv2.VideoCapture(video_src+'/'+i)
        result_list = 0
        for i in range(0, 32):
          if(type(result_list)==type(0)):
            read_val = cv2.resize(test_video.read()[1], (224, 224))
            read_val = read_val/255
            result_list = read_val.reshape(1,224,224,3)
          else:
            read_val = cv2.resize(test_video.read()[1], (224, 224))
            read_val = read_val/255
            read_val = read_val.reshape(1,224,224,3)
            result_list = np.concatenate([result_list, read_val])
        result_list=result_list.reshape(32,-1,3)
        #영상 가져오기 끝
        if(type(return_data)==type(0)):
          return_data = result_list.reshape(1, 32, -1, 3)
        else:
          return_data = np.concatenate([return_data, result_list.reshape(1, 32, -1, 3)])
      return_label = []
      for i in test_load['label']:
        if(i==0):
          target = np.array([1,0])
        else:
          target = np.array([0,1])
        return_label.append(target)
      return_label = np.stack(return_label)
      return return_data, return_label

# %%
train_datagen = DataGenerator(data_train, 2)

# %%
validation_datagen = DataGenerator(data_validation, 2)

# %%
result = train_datagen.__getitem__(0)

# %%
result[1].shape
# Out:
# (2, 2)

# %%
#저장경로
store_tensor_model_path = cur_path+'/trained_models/tensorflow'

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# %%
#callback 학습 시 활용할 함수들
#모델의 weight와 모델의 network구조를 저장함 //verbose=1: 저장했다고 출력해라 // save_best_only=True: 가장좋은거 하나 저장한다
modelcheckpoint=ModelCheckpoint(store_tensor_model_path+'/second_try_no_lstm.h5', monitor='val_loss', verbose=1, save_best_only=True)
#lr스케줄링
lr_schedule = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.0000001)

# %%
#모델을 저장했다가, 나중에 사용할 수 있도록 callback을 사용함, 저장은 로컬에 저장이됨_ 옆에 파일있는곳에 보임
history = model.fit(
    train_datagen,
    validation_data=validation_datagen, 
    epochs=100, # epochs 복수형으로 쓰기!
    callbacks=[modelcheckpoint, lr_schedule]
)
# Out:
# Epoch 1/100
# 346/346 [==============================] - ETA: 0s - loss: 10.1946 - acc: 0.5231 - recall: 0.5116 - precision: 0.4335 - f1score: 0.4491
# Epoch 1: val_loss improved from inf to 0.71639, saving model to /content/drive/Shareddrives/capstone_data_process/temp/trained_models/tensorflow/second_try_no_lstm.h5
# 346/346 [==============================] - 802s 2s/step - loss: 10.1946 - acc: 0.5231 - recall: 0.5116 - precision: 0.4335 - f1score: 0.4491 - val_loss: 0.7164 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 0.0100
# Epoch 2/100
# 346/346 [==============================] - ETA: 0s - loss: 0.9033 - acc: 0.4971 - recall: 0.5246 - precision: 0.4798 - f1score: 0.4743
# Epoch 2: val_loss improved from 0.71639 to 0.71341, saving model to /content/drive/Shareddrives/capstone_data_process/temp/trained_models/tensorflow/second_try_no_lstm.h5
# 346/346 [==============================] - 290s 838ms/step - loss: 0.9033 - acc: 0.4971 - recall: 0.5246 - precision: 0.4798 - f1score: 0.4743 - val_loss: 0.7134 - val_acc: 0.5448 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1score: 0.0000e+00 - lr: 0.0100
# Epoch 3/100
# 346/346 [==============================] - ETA: 0s - loss: 0.7072 - acc: 0.5159 - recall: 0.5087 - precision: 0.4769 - f1score: 0.4700
# Epoch 3: val_loss improved from 0.71341 to 0.69044, saving model to /content/drive/Shareddrives/capstone_data_process/temp/trained_models/tensorflow/second_try_no_lstm.h5
# 346/346 [==============================] - 284s 820ms/step - loss: 0.7072 - acc: 0.5159 - recall: 0.5087 - precision: 0.4769 - f1score: 0.4700 - val_loss: 0.6904 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 0.0100
# Epoch 4/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6984 - acc: 0.5145 - recall: 0.4798 - precision: 0.4581 - f1score: 0.4505
# Epoch 4: val_loss improved from 0.69044 to 0.68996, saving model to /content/drive/Shareddrives/capstone_data_process/temp/trained_models/tensorflow/second_try_no_lstm.h5
# 346/346 [==============================] - 284s 819ms/step - loss: 0.6984 - acc: 0.5145 - recall: 0.4798 - precision: 0.4581 - f1score: 0.4505 - val_loss: 0.6900 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 0.0100
# Epoch 5/100
# 346/346 [==============================] - ETA: 0s - loss: 0.7044 - acc: 0.5173 - recall: 0.5130 - precision: 0.4822 - f1score: 0.4762
# Epoch 5: val_loss did not improve from 0.68996
# 346/346 [==============================] - 279s 806ms/step - loss: 0.7044 - acc: 0.5173 - recall: 0.5130 - precision: 0.4822 - f1score: 0.4762 - val_loss: 0.6908 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 0.0100
# Epoch 6/100
# 346/346 [==============================] - ETA: 0s - loss: 0.7443 - acc: 0.5130 - recall: 0.5520 - precision: 0.4542 - f1score: 0.4759
# Epoch 6: val_loss improved from 0.68996 to 0.68905, saving model to /content/drive/Shareddrives/capstone_data_process/temp/trained_models/tensorflow/second_try_no_lstm.h5
# 346/346 [==============================] - 286s 828ms/step - loss: 0.7443 - acc: 0.5130 - recall: 0.5520 - precision: 0.4542 - f1score: 0.4759 - val_loss: 0.6890 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 0.0100
# Epoch 7/100
# 346/346 [==============================] - ETA: 0s - loss: 0.7147 - acc: 0.4870 - recall: 0.4957 - precision: 0.4528 - f1score: 0.4509
# Epoch 7: val_loss did not improve from 0.68905
# 346/346 [==============================] - 288s 832ms/step - loss: 0.7147 - acc: 0.4870 - recall: 0.4957 - precision: 0.4528 - f1score: 0.4509 - val_loss: 0.7026 - val_acc: 0.4422 - val_recall: 0.0202 - val_precision: 0.0405 - val_f1score: 0.0270 - lr: 0.0100
# Epoch 8/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6996 - acc: 0.5043 - recall: 0.4754 - precision: 0.4803 - f1score: 0.4617
# Epoch 8: val_loss did not improve from 0.68905
# 346/346 [==============================] - 289s 834ms/step - loss: 0.6996 - acc: 0.5043 - recall: 0.4754 - precision: 0.4803 - f1score: 0.4617 - val_loss: 0.6935 - val_acc: 0.4740 - val_recall: 1.0000 - val_precision: 0.5000 - val_f1score: 0.6667 - lr: 0.0100
# Epoch 9/100
# 346/346 [==============================] - ETA: 0s - loss: 1.3386 - acc: 0.5159 - recall: 0.5101 - precision: 0.4836 - f1score: 0.4795
# Epoch 9: val_loss did not improve from 0.68905
# 346/346 [==============================] - 288s 834ms/step - loss: 1.3386 - acc: 0.5159 - recall: 0.5101 - precision: 0.4836 - f1score: 0.4795 - val_loss: 2.0950 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 0.0100
# Epoch 10/100
# 346/346 [==============================] - ETA: 0s - loss: 1.1086 - acc: 0.4928 - recall: 0.4971 - precision: 0.4870 - f1score: 0.4877
# Epoch 10: val_loss did not improve from 0.68905
# 346/346 [==============================] - 289s 835ms/step - loss: 1.1086 - acc: 0.4928 - recall: 0.4971 - precision: 0.4870 - f1score: 0.4877 - val_loss: 0.6907 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 0.0100
# Epoch 11/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6917 - acc: 0.5101 - recall: 0.5116 - precision: 0.5130 - f1score: 0.5108
# Epoch 11: val_loss did not improve from 0.68905
# 346/346 [==============================] - 289s 836ms/step - loss: 0.6917 - acc: 0.5101 - recall: 0.5116 - precision: 0.5130 - f1score: 0.5108 - val_loss: 0.6943 - val_acc: 0.4552 - val_recall: 0.4552 - val_precision: 0.4552 - val_f1score: 0.4552 - lr: 0.0100
# Epoch 12/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6931 - acc: 0.5116 - recall: 0.5289 - precision: 0.5130 - f1score: 0.5100
# Epoch 12: val_loss did not improve from 0.68905
# 346/346 [==============================] - 289s 836ms/step - loss: 0.6931 - acc: 0.5116 - recall: 0.5289 - precision: 0.5130 - f1score: 0.5100 - val_loss: 0.6933 - val_acc: 0.5029 - val_recall: 0.5029 - val_precision: 0.5029 - val_f1score: 0.5029 - lr: 1.0000e-03
# Epoch 13/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6917 - acc: 0.5390 - recall: 0.5679 - precision: 0.5356 - f1score: 0.5474
# Epoch 13: val_loss did not improve from 0.68905
# 346/346 [==============================] - 289s 836ms/step - loss: 0.6917 - acc: 0.5390 - recall: 0.5679 - precision: 0.5356 - f1score: 0.5474 - val_loss: 0.6934 - val_acc: 0.4668 - val_recall: 0.4668 - val_precision: 0.4668 - val_f1score: 0.4668 - lr: 1.0000e-03
# Epoch 14/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6901 - acc: 0.5491 - recall: 0.5708 - precision: 0.5544 - f1score: 0.5605
# Epoch 14: val_loss did not improve from 0.68905
# 346/346 [==============================] - 287s 831ms/step - loss: 0.6901 - acc: 0.5491 - recall: 0.5708 - precision: 0.5544 - f1score: 0.5605 - val_loss: 0.6903 - val_acc: 0.5217 - val_recall: 0.5217 - val_precision: 0.5217 - val_f1score: 0.5217 - lr: 1.0000e-03
# Epoch 15/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6931 - acc: 0.5101 - recall: 0.5679 - precision: 0.5169 - f1score: 0.5369
# Epoch 15: val_loss did not improve from 0.68905
# 346/346 [==============================] - 288s 832ms/step - loss: 0.6931 - acc: 0.5101 - recall: 0.5679 - precision: 0.5169 - f1score: 0.5369 - val_loss: 0.6909 - val_acc: 0.5246 - val_recall: 0.5217 - val_precision: 0.5231 - val_f1score: 0.5222 - lr: 1.0000e-03
# Epoch 16/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6942 - acc: 0.5260 - recall: 0.5405 - precision: 0.5255 - f1score: 0.5294
# Epoch 16: val_loss did not improve from 0.68905
# 346/346 [==============================] - 287s 830ms/step - loss: 0.6942 - acc: 0.5260 - recall: 0.5405 - precision: 0.5255 - f1score: 0.5294 - val_loss: 0.6919 - val_acc: 0.5043 - val_recall: 0.5043 - val_precision: 0.5043 - val_f1score: 0.5043 - lr: 1.0000e-03
# Epoch 17/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6914 - acc: 0.5477 - recall: 0.5405 - precision: 0.5501 - f1score: 0.5435
# Epoch 17: val_loss did not improve from 0.68905
# 346/346 [==============================] - 287s 830ms/step - loss: 0.6914 - acc: 0.5477 - recall: 0.5405 - precision: 0.5501 - f1score: 0.5435 - val_loss: 0.6919 - val_acc: 0.5087 - val_recall: 0.5087 - val_precision: 0.5087 - val_f1score: 0.5087 - lr: 1.0000e-04
# Epoch 18/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6910 - acc: 0.5477 - recall: 0.5434 - precision: 0.5448 - f1score: 0.5438
# Epoch 18: val_loss did not improve from 0.68905
# 346/346 [==============================] - 288s 832ms/step - loss: 0.6910 - acc: 0.5477 - recall: 0.5434 - precision: 0.5448 - f1score: 0.5438 - val_loss: 0.6917 - val_acc: 0.5101 - val_recall: 0.5101 - val_precision: 0.5159 - val_f1score: 0.5120 - lr: 1.0000e-04
# Epoch 19/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6895 - acc: 0.5592 - recall: 0.5592 - precision: 0.5554 - f1score: 0.5569
# Epoch 19: val_loss did not improve from 0.68905
# 346/346 [==============================] - 288s 831ms/step - loss: 0.6895 - acc: 0.5592 - recall: 0.5592 - precision: 0.5554 - f1score: 0.5569 - val_loss: 0.6914 - val_acc: 0.5173 - val_recall: 0.5173 - val_precision: 0.5173 - val_f1score: 0.5173 - lr: 1.0000e-04
# Epoch 20/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6890 - acc: 0.5405 - recall: 0.5462 - precision: 0.5414 - f1score: 0.5434
# Epoch 20: val_loss did not improve from 0.68905
# 346/346 [==============================] - 293s 846ms/step - loss: 0.6890 - acc: 0.5405 - recall: 0.5462 - precision: 0.5414 - f1score: 0.5434 - val_loss: 0.6921 - val_acc: 0.5000 - val_recall: 0.5000 - val_precision: 0.5000 - val_f1score: 0.5000 - lr: 1.0000e-04
# Epoch 21/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6907 - acc: 0.5405 - recall: 0.5448 - precision: 0.5419 - f1score: 0.5431
# Epoch 21: val_loss did not improve from 0.68905
# 346/346 [==============================] - 286s 827ms/step - loss: 0.6907 - acc: 0.5405 - recall: 0.5448 - precision: 0.5419 - f1score: 0.5431 - val_loss: 0.6919 - val_acc: 0.5000 - val_recall: 0.5000 - val_precision: 0.5000 - val_f1score: 0.5000 - lr: 1.0000e-04
# Epoch 22/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6900 - acc: 0.5506 - recall: 0.5578 - precision: 0.5487 - f1score: 0.5523
# Epoch 22: val_loss did not improve from 0.68905
# 346/346 [==============================] - 277s 800ms/step - loss: 0.6900 - acc: 0.5506 - recall: 0.5578 - precision: 0.5487 - f1score: 0.5523 - val_loss: 0.6917 - val_acc: 0.4957 - val_recall: 0.4957 - val_precision: 0.4957 - val_f1score: 0.4957 - lr: 1.0000e-05
# Epoch 23/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6900 - acc: 0.5578 - recall: 0.5665 - precision: 0.5530 - f1score: 0.5583
# Epoch 23: val_loss did not improve from 0.68905
# 346/346 [==============================] - 278s 804ms/step - loss: 0.6900 - acc: 0.5578 - recall: 0.5665 - precision: 0.5530 - f1score: 0.5583 - val_loss: 0.6916 - val_acc: 0.5043 - val_recall: 0.4986 - val_precision: 0.5014 - val_f1score: 0.4995 - lr: 1.0000e-05
# Epoch 24/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6882 - acc: 0.5607 - recall: 0.5665 - precision: 0.5607 - f1score: 0.5630
# Epoch 24: val_loss did not improve from 0.68905
# 346/346 [==============================] - 276s 799ms/step - loss: 0.6882 - acc: 0.5607 - recall: 0.5665 - precision: 0.5607 - f1score: 0.5630 - val_loss: 0.6916 - val_acc: 0.5043 - val_recall: 0.5043 - val_precision: 0.5043 - val_f1score: 0.5043 - lr: 1.0000e-05
# Epoch 25/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6902 - acc: 0.5448 - recall: 0.5491 - precision: 0.5462 - f1score: 0.5470
# Epoch 25: val_loss did not improve from 0.68905
# 346/346 [==============================] - 276s 799ms/step - loss: 0.6902 - acc: 0.5448 - recall: 0.5491 - precision: 0.5462 - f1score: 0.5470 - val_loss: 0.6917 - val_acc: 0.5043 - val_recall: 0.5043 - val_precision: 0.5043 - val_f1score: 0.5043 - lr: 1.0000e-05
# Epoch 26/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6906 - acc: 0.5419 - recall: 0.5520 - precision: 0.5419 - f1score: 0.5456
# Epoch 26: val_loss did not improve from 0.68905
# 346/346 [==============================] - 274s 793ms/step - loss: 0.6906 - acc: 0.5419 - recall: 0.5520 - precision: 0.5419 - f1score: 0.5456 - val_loss: 0.6917 - val_acc: 0.5043 - val_recall: 0.4986 - val_precision: 0.5043 - val_f1score: 0.5005 - lr: 1.0000e-05
# Epoch 27/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6924 - acc: 0.5390 - recall: 0.5462 - precision: 0.5395 - f1score: 0.5418
# Epoch 27: val_loss did not improve from 0.68905
# 346/346 [==============================] - 276s 797ms/step - loss: 0.6924 - acc: 0.5390 - recall: 0.5462 - precision: 0.5395 - f1score: 0.5418 - val_loss: 0.6917 - val_acc: 0.5029 - val_recall: 0.5029 - val_precision: 0.5029 - val_f1score: 0.5029 - lr: 1.0000e-06
# Epoch 28/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6888 - acc: 0.5780 - recall: 0.5838 - precision: 0.5766 - f1score: 0.5795
# Epoch 28: val_loss did not improve from 0.68905
# 346/346 [==============================] - 275s 796ms/step - loss: 0.6888 - acc: 0.5780 - recall: 0.5838 - precision: 0.5766 - f1score: 0.5795 - val_loss: 0.6917 - val_acc: 0.5029 - val_recall: 0.5029 - val_precision: 0.5029 - val_f1score: 0.5029 - lr: 1.0000e-06
# Epoch 29/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6901 - acc: 0.5477 - recall: 0.5592 - precision: 0.5506 - f1score: 0.5537
# Epoch 29: val_loss did not improve from 0.68905
# 346/346 [==============================] - 275s 796ms/step - loss: 0.6901 - acc: 0.5477 - recall: 0.5592 - precision: 0.5506 - f1score: 0.5537 - val_loss: 0.6918 - val_acc: 0.5029 - val_recall: 0.5029 - val_precision: 0.5029 - val_f1score: 0.5029 - lr: 1.0000e-06
# Epoch 30/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6911 - acc: 0.5535 - recall: 0.5737 - precision: 0.5559 - f1score: 0.5630
# Epoch 30: val_loss did not improve from 0.68905
# 346/346 [==============================] - 275s 794ms/step - loss: 0.6911 - acc: 0.5535 - recall: 0.5737 - precision: 0.5559 - f1score: 0.5630 - val_loss: 0.6921 - val_acc: 0.5029 - val_recall: 0.5029 - val_precision: 0.5029 - val_f1score: 0.5029 - lr: 1.0000e-06
# Epoch 31/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6905 - acc: 0.5448 - recall: 0.5564 - precision: 0.5438 - f1score: 0.5485
# Epoch 31: val_loss did not improve from 0.68905
# 346/346 [==============================] - 274s 792ms/step - loss: 0.6905 - acc: 0.5448 - recall: 0.5564 - precision: 0.5438 - f1score: 0.5485 - val_loss: 0.6922 - val_acc: 0.5029 - val_recall: 0.5029 - val_precision: 0.5029 - val_f1score: 0.5029 - lr: 1.0000e-06
# Epoch 32/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6893 - acc: 0.5592 - recall: 0.5665 - precision: 0.5568 - f1score: 0.5603
# Epoch 32: val_loss did not improve from 0.68905
# 346/346 [==============================] - 274s 792ms/step - loss: 0.6893 - acc: 0.5592 - recall: 0.5665 - precision: 0.5568 - f1score: 0.5603 - val_loss: 0.6926 - val_acc: 0.5029 - val_recall: 0.5029 - val_precision: 0.5029 - val_f1score: 0.5029 - lr: 1.0000e-07
# Epoch 33/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6914 - acc: 0.5491 - recall: 0.5592 - precision: 0.5511 - f1score: 0.5543
# Epoch 33: val_loss did not improve from 0.68905
# 346/346 [==============================] - 274s 791ms/step - loss: 0.6914 - acc: 0.5491 - recall: 0.5592 - precision: 0.5511 - f1score: 0.5543 - val_loss: 0.6926 - val_acc: 0.5029 - val_recall: 0.5029 - val_precision: 0.5029 - val_f1score: 0.5029 - lr: 1.0000e-07
# Epoch 34/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6878 - acc: 0.5448 - recall: 0.5607 - precision: 0.5496 - f1score: 0.5532
# Epoch 34: val_loss did not improve from 0.68905
# 346/346 [==============================] - 272s 785ms/step - loss: 0.6878 - acc: 0.5448 - recall: 0.5607 - precision: 0.5496 - f1score: 0.5532 - val_loss: 0.6927 - val_acc: 0.5029 - val_recall: 0.5029 - val_precision: 0.5029 - val_f1score: 0.5029 - lr: 1.0000e-07
# Epoch 35/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6904 - acc: 0.5405 - recall: 0.5535 - precision: 0.5419 - f1score: 0.5461
# Epoch 35: val_loss did not improve from 0.68905
# 346/346 [==============================] - 272s 785ms/step - loss: 0.6904 - acc: 0.5405 - recall: 0.5535 - precision: 0.5419 - f1score: 0.5461 - val_loss: 0.6927 - val_acc: 0.4971 - val_recall: 0.4971 - val_precision: 0.5000 - val_f1score: 0.4981 - lr: 1.0000e-07
# Epoch 36/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6877 - acc: 0.5564 - recall: 0.5679 - precision: 0.5573 - f1score: 0.5612
# Epoch 36: val_loss did not improve from 0.68905
# 346/346 [==============================] - 272s 787ms/step - loss: 0.6877 - acc: 0.5564 - recall: 0.5679 - precision: 0.5573 - f1score: 0.5612 - val_loss: 0.6928 - val_acc: 0.4971 - val_recall: 0.4928 - val_precision: 0.4942 - val_f1score: 0.4933 - lr: 1.0000e-07
# Epoch 37/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6897 - acc: 0.5390 - recall: 0.5506 - precision: 0.5443 - f1score: 0.5468
# Epoch 37: val_loss did not improve from 0.68905
# 346/346 [==============================] - 271s 782ms/step - loss: 0.6897 - acc: 0.5390 - recall: 0.5506 - precision: 0.5443 - f1score: 0.5468 - val_loss: 0.6930 - val_acc: 0.4928 - val_recall: 0.4928 - val_precision: 0.4928 - val_f1score: 0.4928 - lr: 1.0000e-07
# Epoch 38/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6901 - acc: 0.5448 - recall: 0.5520 - precision: 0.5458 - f1score: 0.5483
# Epoch 38: val_loss did not improve from 0.68905
# 346/346 [==============================] - 271s 782ms/step - loss: 0.6901 - acc: 0.5448 - recall: 0.5520 - precision: 0.5458 - f1score: 0.5483 - val_loss: 0.6930 - val_acc: 0.4928 - val_recall: 0.4928 - val_precision: 0.4928 - val_f1score: 0.4928 - lr: 1.0000e-07
# Epoch 39/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6904 - acc: 0.5448 - recall: 0.5535 - precision: 0.5429 - f1score: 0.5471
# Epoch 39: val_loss did not improve from 0.68905
# 346/346 [==============================] - 272s 786ms/step - loss: 0.6904 - acc: 0.5448 - recall: 0.5535 - precision: 0.5429 - f1score: 0.5471 - val_loss: 0.6930 - val_acc: 0.4928 - val_recall: 0.4928 - val_precision: 0.4928 - val_f1score: 0.4928 - lr: 1.0000e-07
# Epoch 40/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6900 - acc: 0.5434 - recall: 0.5636 - precision: 0.5458 - f1score: 0.5529
# Epoch 40: val_loss did not improve from 0.68905
# 346/346 [==============================] - 272s 786ms/step - loss: 0.6900 - acc: 0.5434 - recall: 0.5636 - precision: 0.5458 - f1score: 0.5529 - val_loss: 0.6930 - val_acc: 0.4928 - val_recall: 0.4928 - val_precision: 0.4928 - val_f1score: 0.4928 - lr: 1.0000e-07
# Epoch 41/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6916 - acc: 0.5434 - recall: 0.5506 - precision: 0.5429 - f1score: 0.5460
# Epoch 41: val_loss did not improve from 0.68905
# 346/346 [==============================] - 272s 786ms/step - loss: 0.6916 - acc: 0.5434 - recall: 0.5506 - precision: 0.5429 - f1score: 0.5460 - val_loss: 0.6930 - val_acc: 0.4928 - val_recall: 0.4928 - val_precision: 0.4928 - val_f1score: 0.4928 - lr: 1.0000e-07
# Epoch 42/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6863 - acc: 0.5520 - recall: 0.5607 - precision: 0.5544 - f1score: 0.5566
# Epoch 42: val_loss did not improve from 0.68905
# 346/346 [==============================] - 267s 772ms/step - loss: 0.6863 - acc: 0.5520 - recall: 0.5607 - precision: 0.5544 - f1score: 0.5566 - val_loss: 0.6930 - val_acc: 0.4928 - val_recall: 0.4928 - val_precision: 0.4928 - val_f1score: 0.4928 - lr: 1.0000e-07
# Epoch 43/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6906 - acc: 0.5535 - recall: 0.5679 - precision: 0.5530 - f1score: 0.5590
# Epoch 43: val_loss did not improve from 0.68905
# 346/346 [==============================] - 268s 775ms/step - loss: 0.6906 - acc: 0.5535 - recall: 0.5679 - precision: 0.5530 - f1score: 0.5590 - val_loss: 0.6929 - val_acc: 0.4928 - val_recall: 0.4928 - val_precision: 0.4928 - val_f1score: 0.4928 - lr: 1.0000e-07
# Epoch 44/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6895 - acc: 0.5564 - recall: 0.5665 - precision: 0.5539 - f1score: 0.5590
# Epoch 44: val_loss did not improve from 0.68905
# 346/346 [==============================] - 274s 793ms/step - loss: 0.6895 - acc: 0.5564 - recall: 0.5665 - precision: 0.5539 - f1score: 0.5590 - val_loss: 0.6930 - val_acc: 0.4928 - val_recall: 0.4928 - val_precision: 0.4928 - val_f1score: 0.4928 - lr: 1.0000e-07
# Epoch 45/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6914 - acc: 0.5419 - recall: 0.5578 - precision: 0.5438 - f1score: 0.5494
# Epoch 45: val_loss did not improve from 0.68905
# 346/346 [==============================] - 275s 795ms/step - loss: 0.6914 - acc: 0.5419 - recall: 0.5578 - precision: 0.5438 - f1score: 0.5494 - val_loss: 0.6930 - val_acc: 0.4928 - val_recall: 0.4928 - val_precision: 0.4928 - val_f1score: 0.4928 - lr: 1.0000e-07
# Epoch 46/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6892 - acc: 0.5650 - recall: 0.5679 - precision: 0.5612 - f1score: 0.5639
# Epoch 46: val_loss did not improve from 0.68905
# 346/346 [==============================] - 272s 786ms/step - loss: 0.6892 - acc: 0.5650 - recall: 0.5679 - precision: 0.5612 - f1score: 0.5639 - val_loss: 0.6930 - val_acc: 0.4928 - val_recall: 0.4928 - val_precision: 0.4928 - val_f1score: 0.4928 - lr: 1.0000e-07
# Epoch 47/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6892 - acc: 0.5549 - recall: 0.5636 - precision: 0.5559 - f1score: 0.5590
# Epoch 47: val_loss did not improve from 0.68905
# 346/346 [==============================] - 274s 793ms/step - loss: 0.6892 - acc: 0.5549 - recall: 0.5636 - precision: 0.5559 - f1score: 0.5590 - val_loss: 0.6929 - val_acc: 0.4928 - val_recall: 0.4928 - val_precision: 0.4928 - val_f1score: 0.4928 - lr: 1.0000e-07
# Epoch 48/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6891 - acc: 0.5564 - recall: 0.5650 - precision: 0.5535 - f1score: 0.5576
# Epoch 48: val_loss did not improve from 0.68905
# 346/346 [==============================] - 275s 795ms/step - loss: 0.6891 - acc: 0.5564 - recall: 0.5650 - precision: 0.5535 - f1score: 0.5576 - val_loss: 0.6930 - val_acc: 0.4928 - val_recall: 0.4928 - val_precision: 0.4928 - val_f1score: 0.4928 - lr: 1.0000e-07
# Epoch 49/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6908 - acc: 0.5549 - recall: 0.5636 - precision: 0.5535 - f1score: 0.5575
# Epoch 49: val_loss did not improve from 0.68905
# 346/346 [==============================] - 274s 791ms/step - loss: 0.6908 - acc: 0.5549 - recall: 0.5636 - precision: 0.5535 - f1score: 0.5575 - val_loss: 0.6930 - val_acc: 0.4928 - val_recall: 0.4928 - val_precision: 0.4928 - val_f1score: 0.4928 - lr: 1.0000e-07
# Epoch 50/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6887 - acc: 0.5520 - recall: 0.5665 - precision: 0.5602 - f1score: 0.5619
# Epoch 50: val_loss did not improve from 0.68905
# 346/346 [==============================] - 275s 794ms/step - loss: 0.6887 - acc: 0.5520 - recall: 0.5665 - precision: 0.5602 - f1score: 0.5619 - val_loss: 0.6929 - val_acc: 0.4928 - val_recall: 0.4928 - val_precision: 0.4928 - val_f1score: 0.4928 - lr: 1.0000e-07
# Epoch 51/100
#  54/346 [===>..........................] - ETA: 2:14 - loss: 0.6943 - acc: 0.5463 - recall: 0.5463 - precision: 0.5401 - f1score: 0.5426
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-00c84dd234b2> in <module>()
#       4     validation_data=validation_datagen,
#       5     epochs=100, # epochs 복수형으로 쓰기!
# ----> 6     callbacks=[modelcheckpoint, lr_schedule]
#       7 )
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1387               logs = tmp_logs  # No error, now safe to assign to logs.
#    1388               end_step = step + data_handler.step_increment
# -> 1389               callbacks.on_train_batch_end(end_step, logs)
#    1390               if self.stop_training:
#    1391                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     436     """
#     437     if self._should_call_train_batch_hooks:
# --> 438       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     439
#     440   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     295       self._call_batch_begin_hook(mode, batch, logs)
#     296     elif hook == 'end':
# --> 297       self._call_batch_end_hook(mode, batch, logs)
#     298     else:
#     299       raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     316       self._batch_times.append(batch_time)
#     317
# --> 318     self._call_batch_hook_helper(hook_name, batch, logs)
#     319
#     320     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354     for callback in self.callbacks:
#     355       hook = getattr(callback, hook_name)
# --> 356       hook(batch, logs)
#     357
#     358     if self._check_timing:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1032
#    1033   def on_train_batch_end(self, batch, logs=None):
# -> 1034     self._batch_update_progbar(batch, logs)
#    1035
#    1036   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1104     if self.verbose == 1:
#    1105       # Only block async when verbose = 1.
# -> 1106       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1107       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1108
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     561     return t.item() if np.ndim(t) == 0 else t
#     562
# --> 563   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     564
#     565
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     555     # Don't turn ragged or sparse tensors to NumPy.
#     556     if isinstance(t, tf.Tensor):
# --> 557       t = t.numpy()
#     558     # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     559     if not isinstance(t, (np.ndarray, np.generic)):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1221     """
#    1222     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1223     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1224     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1225
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1187   def _numpy(self):
#    1188     try:
# -> 1189       return self._numpy_internal()
#    1190     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1191       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
#history = model.fit(x_train, y_train, validation_split=0.25, epochs=10, verbose=1)
#print(history.history)
#
## 6 훈련 과정 시각화 (정확도)
#plt.plot(history.history['accuracy'])
#plt.plot(history.history['val_accuracy'])
#plt.title('Model accuracy')
#plt.xlabel('Epoch')
#plt.ylabel('Accuracy')
#plt.legend(['Train', 'Test'], loc='upper left')
#plt.show()
#
## 7 훈련 과정 시각화 (손실)
#plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
#plt.title('Model loss')
#plt.xlabel('Epoch')
#plt.ylabel('Loss')
#plt.legend(['Train', 'Test'], loc='upper left')
#plt.show()
