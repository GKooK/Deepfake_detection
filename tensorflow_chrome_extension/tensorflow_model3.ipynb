# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import Sequence
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten, Dropout, LSTM, Reshape, LeakyReLU
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

# %%
import tensorflow as tf
import keras.applications as keras_application

# %%
from keras import backend as K
def recall(y_target, y_pred):
    # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
    # round : 반올림한다
    y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다

    # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 

    # (True Positive + False Negative) = 실제 값이 1(Positive) 전체
    count_true_positive_false_negative = K.sum(y_target_yn)

    # Recall =  (True Positive) / (True Positive + False Negative)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    recall = count_true_positive / (count_true_positive_false_negative + K.epsilon())

    # return a single tensor value
    return recall

def precision(y_target, y_pred):
    # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
    # round : 반올림한다
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다
    y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다

    # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 

    # (True Positive + False Positive) = 예측 값이 1(Positive) 전체
    count_true_positive_false_positive = K.sum(y_pred_yn)

    # Precision = (True Positive) / (True Positive + False Positive)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    precision = count_true_positive / (count_true_positive_false_positive + K.epsilon())

    # return a single tensor value
    return precision

def f1score(y_target, y_pred):
    _recall = recall(y_target, y_pred)
    _precision = precision(y_target, y_pred)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    _f1score = ( 2 * _recall * _precision) / (_recall + _precision+ K.epsilon())
    
    # return a single tensor value
    return _f1score

# %%
from keras.applications import mobilenet_v2

# %%
img_row,img_col=224,224
temp_mobile = mobilenet_v2.MobileNetV2(weights='imagenet', include_top=False, input_shape=(32,img_row*img_col,3), pooling='max')
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
#temp_mobile.summary()

# %%
model=Sequential()

# %%
model.add(temp_mobile)

# %%
model.add(Dense(80, input_shape=(1280,)))

# %%
model.add(LeakyReLU())

# %%
model.add(Dense(5, input_shape=(80,)))

# %%
model.add(LeakyReLU())

# %%
model.add(Dropout(rate=0.7))

# %%
model.add(Dense(2, activation='sigmoid'))

# %%
model.compile(loss=tf.keras.losses.BinaryCrossentropy(), optimizer=SGD(learning_rate=0.01), metrics=['acc', recall, precision, f1score])
#lr 스케줄링은 나중에model.fit의 callback안에 넣어주자.
#아래와 같이하면됨
#reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
#                              patience=5, min_lr=0.001)
#model.fit(X_train, Y_train, callbacks=[reduce_lr])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 1280)             2257984
#  ional)
#
#  dense (Dense)               (None, 80)                102480
#
#  leaky_re_lu (LeakyReLU)     (None, 80)                0
#
#  dense_1 (Dense)             (None, 5)                 405
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 5)                 0
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 2,360,881
# Trainable params: 2,326,769
# Non-trainable params: 34,112
# _________________________________________________________________

# %%
#model.save('temp_ml5.h5')

# %%
#sample_data
#test = tf.random.uniform([16,32,224*224,3],0,1)
#배치 크기 16쓰자

# %%
import os
cur_path = os.getcwd()
cur_path+='/drive/Shareddrives/capstone_data_process/temp'
video_src = cur_path+'/celeb-df_v2/pre_process/mixed'

# %%
import os
import cv2
cur_path = os.getcwd()
cur_path+='/drive/Shareddrives/capstone_data_process/temp'
all_data = pd.read_csv((cur_path+'/celeb-df_v2/video_data.csv'), names=['file_name', 'label'])
real_num = len(all_data[all_data['label'] == 1])
fake_num = len(all_data[all_data['label'] == 0])
print(real_num, fake_num , real_num+fake_num)
real_alls = all_data[all_data['label'] == 1]
fake_sample = all_data[all_data['label'] == 0].sample(frac=0.11)
all_data_subset = pd.concat([real_alls, fake_sample])
display(all_data_subset)
data_train, data_test = train_test_split(all_data_subset, test_size = 0.2, random_state=2022)
#data_train, data_validation = train_test_split(data_train, test_size=0.25, random_state=2022)
#print(len(data_train), len(data_validation), len(data_test))
print(len(data_train), len(data_test))
# Out:
# 566 5349 5915
#                file_name  label
# 0           id0_0000.avi      1
# 1           id0_0001.avi      1
# 2           id0_0002.avi      1
# 3           id0_0003.avi      1
# 4           id0_0004.avi      1
# ...                  ...    ...
# 2123    id4_id1_0006.avi      0
# 3135  id45_id46_0009.avi      0
# 2629  id54_id53_0004.avi      0
# 5073    id6_id0_0005.avi      0
# 2831  id30_id35_0000.avi      0
#
# [1154 rows x 2 columns]
# 923 231

# %%
test_load = data_train.sample(n=16, replace=True)

# %%
for i in test_load['file_name']:
  print(i)
# Out:
# id27_0001.avi
# id46_id43_0004.avi
# id58_0006.avi
# id30_id1_0001.avi
# id4_id30_0009.avi
# id28_id16_0000.avi
# id23_0008.avi
# id47_id40_0003.avi
# id35_id37_0009.avi
# id49_id55_0007.avi
# id11_0008.avi
# id31_id34_0008.avi
# id13_0014.avi
# id0_id9_0005.avi
# id52_id53_0000.avi
# id17_id16_0001.avi

# %%
#test_video = cv2.VideoCapture(video_src+'/id32_id30_0000.avi')
#result_list = 0
#for i in range(0, 32):
#  if(type(result_list)==type(0)):
#    read_val = cv2.resize(test_video.read()[1], (224, 224))
#    read_val = read_val/255
#    result_list = read_val.reshape(1,224,224,3)
#  else:
#    read_val = cv2.resize(test_video.read()[1], (224, 224))
#    read_val = read_val/255
#    read_val = read_val.reshape(1,224,224,3)
#    result_list = np.concatenate([result_list, read_val])
#result_list=result_list.reshape(32,-1,3)

# %%
#result_list.shape

# %%
#test_load = data_train.sample(n=16, replace=True)
#return_data = 0
#for i in test_load['file_name']:
#  #영상 가져오기
#  test_video = cv2.VideoCapture(video_src+'/'+i)
#  result_list = 0
#  for i in range(0, 32):
#    if(type(result_list)==type(0)):
#      read_val = cv2.resize(test_video.read()[1], (224, 224))
#      read_val = read_val/255
#      result_list = read_val.reshape(1,224,224,3)
#    else:
#      read_val = cv2.resize(test_video.read()[1], (224, 224))
#      read_val = read_val/255
#      read_val = read_val.reshape(1,224,224,3)
#      result_list = np.concatenate([result_list, read_val])
#  result_list=result_list.reshape(32,-1,3)
#  #영상 가져오기 끝
#  if(type(return_data)==type(0)):
#    return_data = result_list.reshape(1, 32, -1, 3)
#  else:
#    return_data = np.concatenate([return_data, result_list.reshape(1, 32, -1, 3)])
#return_label = []
#for i in test_load['label']:
#  if(i==0):
#    target = np.array([1,0])
#  else:
#    target = np.array([0,1])
#  return_label.append(target)
#return_label = np.stack(return_label)

# %%
#return_label

# %%
#return_data.shape

# %%
#len(data_train)

# %%
class DataGenerator(Sequence):
    def __init__(self, dataset, batch_size):
      self.dataset = dataset
      self.batch_size = batch_size

    def __len__(self):
      return int(len(data_train) / self.batch_size)

    def __getitem__(self, index):
      test_load = self.dataset.sample(n=self.batch_size, replace=True, random_state=index)
      return_data = 0
      for i in test_load['file_name']:
        #영상 가져오기
        test_video = cv2.VideoCapture(video_src+'/'+i)
        result_list = 0
        for i in range(0, 32):
          if(type(result_list)==type(0)):
            read_val = cv2.resize(test_video.read()[1], (224, 224))
            read_val = read_val/255
            result_list = read_val.reshape(1,224,224,3)
          else:
            read_val = cv2.resize(test_video.read()[1], (224, 224))
            read_val = read_val/255
            read_val = read_val.reshape(1,224,224,3)
            result_list = np.concatenate([result_list, read_val])
        result_list=result_list.reshape(32,-1,3)
        #영상 가져오기 끝
        if(type(return_data)==type(0)):
          return_data = result_list.reshape(1, 32, -1, 3)
        else:
          return_data = np.concatenate([return_data, result_list.reshape(1, 32, -1, 3)])
      return_label = []
      for i in test_load['label']:
        if(i==0):
          target = np.array([1,0])
        else:
          target = np.array([0,1])
        return_label.append(target)
      return_label = np.stack(return_label)
      return return_data, return_label

# %%
train_datagen = DataGenerator(data_train, 4)

# %%
validation_datagen = DataGenerator(data_test, 4)

# %%
result = train_datagen.__getitem__(0)

# %%
result[1].shape
# Out:
# (4, 2)

# %%
#저장경로
store_tensor_model_path = cur_path+'/trained_models/tensorflow'

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# %%
#callback 학습 시 활용할 함수들
#모델의 weight와 모델의 network구조를 저장함 //verbose=1: 저장했다고 출력해라 // save_best_only=True: 가장좋은거 하나 저장한다
modelcheckpoint=ModelCheckpoint(store_tensor_model_path+'/third_try_no_lstm_add_activation.h5', monitor='val_loss', verbose=1, save_best_only=True)
#lr스케줄링
lr_schedule = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0000001)

# %%
#모델을 저장했다가, 나중에 사용할 수 있도록 callback을 사용함, 저장은 로컬에 저장이됨_ 옆에 파일있는곳에 보임
history = model.fit(
    train_datagen,
    validation_data=validation_datagen, 
    epochs=100, # epochs 복수형으로 쓰기!
    callbacks=[modelcheckpoint, lr_schedule]
)
# Out:
# Epoch 1/100
# 230/230 [==============================] - ETA: 0s - loss: 1.1643 - acc: 0.4880 - recall: 0.5707 - precision: 0.4815 - f1score: 0.5033
# Epoch 1: val_loss improved from inf to 0.69715, saving model to /content/drive/Shareddrives/capstone_data_process/temp/trained_models/tensorflow/third_try_no_lstm_add_activation.h5
# 230/230 [==============================] - 571s 2s/step - loss: 1.1643 - acc: 0.4880 - recall: 0.5707 - precision: 0.4815 - f1score: 0.5033 - val_loss: 0.6972 - val_acc: 0.4870 - val_recall: 0.7989 - val_precision: 0.4922 - val_f1score: 0.6052 - lr: 0.0100
# Epoch 2/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6971 - acc: 0.5011 - recall: 0.6022 - precision: 0.4887 - f1score: 0.5209
# Epoch 2: val_loss improved from 0.69715 to 0.69431, saving model to /content/drive/Shareddrives/capstone_data_process/temp/trained_models/tensorflow/third_try_no_lstm_add_activation.h5
# 230/230 [==============================] - 366s 2s/step - loss: 0.6971 - acc: 0.5011 - recall: 0.6022 - precision: 0.4887 - f1score: 0.5209 - val_loss: 0.6943 - val_acc: 0.5000 - val_recall: 0.8076 - val_precision: 0.5077 - val_f1score: 0.6201 - lr: 0.0100
# Epoch 3/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6942 - acc: 0.4815 - recall: 0.4967 - precision: 0.4920 - f1score: 0.4756
# Epoch 3: val_loss improved from 0.69431 to 0.69356, saving model to /content/drive/Shareddrives/capstone_data_process/temp/trained_models/tensorflow/third_try_no_lstm_add_activation.h5
# 230/230 [==============================] - 368s 2s/step - loss: 0.6942 - acc: 0.4815 - recall: 0.4967 - precision: 0.4920 - f1score: 0.4756 - val_loss: 0.6936 - val_acc: 0.5087 - val_recall: 0.9250 - val_precision: 0.4946 - val_f1score: 0.6425 - lr: 0.0100
# Epoch 4/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6935 - acc: 0.4826 - recall: 0.6109 - precision: 0.4764 - f1score: 0.5195
# Epoch 4: val_loss did not improve from 0.69356
# 230/230 [==============================] - 366s 2s/step - loss: 0.6935 - acc: 0.4826 - recall: 0.6109 - precision: 0.4764 - f1score: 0.5195 - val_loss: 0.6938 - val_acc: 0.4793 - val_recall: 0.9163 - val_precision: 0.5046 - val_f1score: 0.6466 - lr: 0.0100
# Epoch 5/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6934 - acc: 0.4935 - recall: 0.6543 - precision: 0.4861 - f1score: 0.5482
# Epoch 5: val_loss did not improve from 0.69356
# 230/230 [==============================] - 366s 2s/step - loss: 0.6934 - acc: 0.4935 - recall: 0.6543 - precision: 0.4861 - f1score: 0.5482 - val_loss: 0.6944 - val_acc: 0.4978 - val_recall: 0.9565 - val_precision: 0.5049 - val_f1score: 0.6595 - lr: 0.0100
# Epoch 6/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6934 - acc: 0.4989 - recall: 0.6033 - precision: 0.4964 - f1score: 0.5322
# Epoch 6: val_loss did not improve from 0.69356
# 230/230 [==============================] - 363s 2s/step - loss: 0.6934 - acc: 0.4989 - recall: 0.6033 - precision: 0.4964 - f1score: 0.5322 - val_loss: 0.6940 - val_acc: 0.5109 - val_recall: 0.9435 - val_precision: 0.4972 - val_f1score: 0.6492 - lr: 0.0100
# Epoch 7/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6933 - acc: 0.4924 - recall: 0.5902 - precision: 0.4911 - f1score: 0.5171
# Epoch 7: val_loss improved from 0.69356 to 0.69353, saving model to /content/drive/Shareddrives/capstone_data_process/temp/trained_models/tensorflow/third_try_no_lstm_add_activation.h5
# 230/230 [==============================] - 366s 2s/step - loss: 0.6933 - acc: 0.4924 - recall: 0.5902 - precision: 0.4911 - f1score: 0.5171 - val_loss: 0.6935 - val_acc: 0.5630 - val_recall: 0.9424 - val_precision: 0.5060 - val_f1score: 0.6556 - lr: 0.0100
# Epoch 8/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6934 - acc: 0.4772 - recall: 0.5728 - precision: 0.4707 - f1score: 0.4978
# Epoch 8: val_loss improved from 0.69353 to 0.69329, saving model to /content/drive/Shareddrives/capstone_data_process/temp/trained_models/tensorflow/third_try_no_lstm_add_activation.h5
# 230/230 [==============================] - 366s 2s/step - loss: 0.6934 - acc: 0.4772 - recall: 0.5728 - precision: 0.4707 - f1score: 0.4978 - val_loss: 0.6933 - val_acc: 0.5326 - val_recall: 0.9141 - val_precision: 0.5070 - val_f1score: 0.6478 - lr: 0.0100
# Epoch 9/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6935 - acc: 0.4696 - recall: 0.5924 - precision: 0.4879 - f1score: 0.5152
# Epoch 9: val_loss did not improve from 0.69329
# 230/230 [==============================] - 365s 2s/step - loss: 0.6935 - acc: 0.4696 - recall: 0.5924 - precision: 0.4879 - f1score: 0.5152 - val_loss: 0.6934 - val_acc: 0.5641 - val_recall: 0.8467 - val_precision: 0.5058 - val_f1score: 0.6248 - lr: 0.0100
# Epoch 10/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6935 - acc: 0.5054 - recall: 0.5652 - precision: 0.4775 - f1score: 0.4997
# Epoch 10: val_loss improved from 0.69329 to 0.69266, saving model to /content/drive/Shareddrives/capstone_data_process/temp/trained_models/tensorflow/third_try_no_lstm_add_activation.h5
# 230/230 [==============================] - 366s 2s/step - loss: 0.6935 - acc: 0.5054 - recall: 0.5652 - precision: 0.4775 - f1score: 0.4997 - val_loss: 0.6927 - val_acc: 0.5174 - val_recall: 0.5337 - val_precision: 0.4951 - val_f1score: 0.4912 - lr: 0.0100
# Epoch 11/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6939 - acc: 0.5022 - recall: 0.4957 - precision: 0.4874 - f1score: 0.4706
# Epoch 11: val_loss did not improve from 0.69266
# 230/230 [==============================] - 363s 2s/step - loss: 0.6939 - acc: 0.5022 - recall: 0.4957 - precision: 0.4874 - f1score: 0.4706 - val_loss: 0.6931 - val_acc: 0.5043 - val_recall: 0.6511 - val_precision: 0.4987 - val_f1score: 0.5573 - lr: 0.0100
# Epoch 12/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6936 - acc: 0.4870 - recall: 0.6370 - precision: 0.4949 - f1score: 0.5433
# Epoch 12: val_loss did not improve from 0.69266
# 230/230 [==============================] - 367s 2s/step - loss: 0.6936 - acc: 0.4870 - recall: 0.6370 - precision: 0.4949 - f1score: 0.5433 - val_loss: 0.6931 - val_acc: 0.5076 - val_recall: 0.6196 - val_precision: 0.4902 - val_f1score: 0.5374 - lr: 0.0100
# Epoch 13/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6934 - acc: 0.4750 - recall: 0.6554 - precision: 0.4957 - f1score: 0.5468
# Epoch 13: val_loss did not improve from 0.69266
# 230/230 [==============================] - 369s 2s/step - loss: 0.6934 - acc: 0.4750 - recall: 0.6554 - precision: 0.4957 - f1score: 0.5468 - val_loss: 0.6933 - val_acc: 0.4957 - val_recall: 0.6304 - val_precision: 0.4866 - val_f1score: 0.5450 - lr: 0.0100
# Epoch 14/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6935 - acc: 0.4902 - recall: 0.5315 - precision: 0.4662 - f1score: 0.4818
# Epoch 14: val_loss did not improve from 0.69266
# 230/230 [==============================] - 364s 2s/step - loss: 0.6935 - acc: 0.4902 - recall: 0.5315 - precision: 0.4662 - f1score: 0.4818 - val_loss: 0.6931 - val_acc: 0.5098 - val_recall: 0.4609 - val_precision: 0.4870 - val_f1score: 0.4645 - lr: 0.0100
# Epoch 15/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6935 - acc: 0.4978 - recall: 0.6674 - precision: 0.4882 - f1score: 0.5533
# Epoch 15: val_loss did not improve from 0.69266
# 230/230 [==============================] - 366s 2s/step - loss: 0.6935 - acc: 0.4978 - recall: 0.6674 - precision: 0.4882 - f1score: 0.5533 - val_loss: 0.6932 - val_acc: 0.5283 - val_recall: 0.8543 - val_precision: 0.4857 - val_f1score: 0.6135 - lr: 0.0100
# Epoch 16/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6932 - acc: 0.4967 - recall: 0.7217 - precision: 0.5057 - f1score: 0.5805
# Epoch 16: val_loss did not improve from 0.69266
# 230/230 [==============================] - 365s 2s/step - loss: 0.6932 - acc: 0.4967 - recall: 0.7217 - precision: 0.5057 - f1score: 0.5805 - val_loss: 0.6932 - val_acc: 0.5109 - val_recall: 0.8435 - val_precision: 0.4942 - val_f1score: 0.6182 - lr: 0.0020
# Epoch 17/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6933 - acc: 0.4935 - recall: 0.7315 - precision: 0.4959 - f1score: 0.5774
# Epoch 17: val_loss did not improve from 0.69266
# 230/230 [==============================] - 372s 2s/step - loss: 0.6933 - acc: 0.4935 - recall: 0.7315 - precision: 0.4959 - f1score: 0.5774 - val_loss: 0.6932 - val_acc: 0.5022 - val_recall: 0.9185 - val_precision: 0.4889 - val_f1score: 0.6368 - lr: 0.0020
# Epoch 18/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6929 - acc: 0.5293 - recall: 0.7261 - precision: 0.5108 - f1score: 0.5870
# Epoch 18: val_loss did not improve from 0.69266
# 230/230 [==============================] - 369s 2s/step - loss: 0.6929 - acc: 0.5293 - recall: 0.7261 - precision: 0.5108 - f1score: 0.5870 - val_loss: 0.6932 - val_acc: 0.4957 - val_recall: 0.5500 - val_precision: 0.5016 - val_f1score: 0.5219 - lr: 0.0020
# Epoch 19/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6932 - acc: 0.4880 - recall: 0.7511 - precision: 0.4968 - f1score: 0.5859
# Epoch 19: val_loss did not improve from 0.69266
# 230/230 [==============================] - 367s 2s/step - loss: 0.6932 - acc: 0.4880 - recall: 0.7511 - precision: 0.4968 - f1score: 0.5859 - val_loss: 0.6932 - val_acc: 0.4880 - val_recall: 0.9772 - val_precision: 0.5003 - val_f1score: 0.6613 - lr: 0.0020
# Epoch 20/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6930 - acc: 0.5098 - recall: 0.6543 - precision: 0.4991 - f1score: 0.5526
# Epoch 20: val_loss did not improve from 0.69266
# 230/230 [==============================] - 371s 2s/step - loss: 0.6930 - acc: 0.5098 - recall: 0.6543 - precision: 0.4991 - f1score: 0.5526 - val_loss: 0.6932 - val_acc: 0.5022 - val_recall: 0.7511 - val_precision: 0.4962 - val_f1score: 0.5944 - lr: 0.0020
# Epoch 21/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6928 - acc: 0.5109 - recall: 0.6609 - precision: 0.5139 - f1score: 0.5645
# Epoch 21: val_loss did not improve from 0.69266
# 230/230 [==============================] - 372s 2s/step - loss: 0.6928 - acc: 0.5109 - recall: 0.6609 - precision: 0.5139 - f1score: 0.5645 - val_loss: 0.6932 - val_acc: 0.5087 - val_recall: 0.8207 - val_precision: 0.5110 - val_f1score: 0.6269 - lr: 4.0000e-04
# Epoch 22/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6927 - acc: 0.5217 - recall: 0.6098 - precision: 0.5053 - f1score: 0.5404
# Epoch 22: val_loss did not improve from 0.69266
# 230/230 [==============================] - 368s 2s/step - loss: 0.6927 - acc: 0.5217 - recall: 0.6098 - precision: 0.5053 - f1score: 0.5404 - val_loss: 0.6933 - val_acc: 0.4957 - val_recall: 0.7043 - val_precision: 0.5081 - val_f1score: 0.5862 - lr: 4.0000e-04
# Epoch 23/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6926 - acc: 0.5120 - recall: 0.6500 - precision: 0.5119 - f1score: 0.5611
# Epoch 23: val_loss did not improve from 0.69266
# 230/230 [==============================] - 371s 2s/step - loss: 0.6926 - acc: 0.5120 - recall: 0.6500 - precision: 0.5119 - f1score: 0.5611 - val_loss: 0.6933 - val_acc: 0.4717 - val_recall: 0.9902 - val_precision: 0.4997 - val_f1score: 0.6640 - lr: 4.0000e-04
# Epoch 24/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6927 - acc: 0.5000 - recall: 0.6391 - precision: 0.5076 - f1score: 0.5541
# Epoch 24: val_loss did not improve from 0.69266
# 230/230 [==============================] - 369s 2s/step - loss: 0.6927 - acc: 0.5000 - recall: 0.6391 - precision: 0.5076 - f1score: 0.5541 - val_loss: 0.6933 - val_acc: 0.5293 - val_recall: 0.9435 - val_precision: 0.4918 - val_f1score: 0.6454 - lr: 4.0000e-04
# Epoch 25/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6925 - acc: 0.5152 - recall: 0.6054 - precision: 0.5106 - f1score: 0.5368
# Epoch 25: val_loss did not improve from 0.69266
# 230/230 [==============================] - 364s 2s/step - loss: 0.6925 - acc: 0.5152 - recall: 0.6054 - precision: 0.5106 - f1score: 0.5368 - val_loss: 0.6933 - val_acc: 0.4859 - val_recall: 0.9641 - val_precision: 0.4938 - val_f1score: 0.6525 - lr: 4.0000e-04
# Epoch 26/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6924 - acc: 0.5250 - recall: 0.5783 - precision: 0.4946 - f1score: 0.5194
# Epoch 26: val_loss did not improve from 0.69266
# 230/230 [==============================] - 371s 2s/step - loss: 0.6924 - acc: 0.5250 - recall: 0.5783 - precision: 0.4946 - f1score: 0.5194 - val_loss: 0.6934 - val_acc: 0.4630 - val_recall: 0.9446 - val_precision: 0.4931 - val_f1score: 0.6466 - lr: 8.0000e-05
# Epoch 27/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6927 - acc: 0.4902 - recall: 0.5652 - precision: 0.4848 - f1score: 0.5062
# Epoch 27: val_loss did not improve from 0.69266
# 230/230 [==============================] - 372s 2s/step - loss: 0.6927 - acc: 0.4902 - recall: 0.5652 - precision: 0.4848 - f1score: 0.5062 - val_loss: 0.6933 - val_acc: 0.4859 - val_recall: 0.8793 - val_precision: 0.4925 - val_f1score: 0.6283 - lr: 8.0000e-05
# Epoch 28/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6923 - acc: 0.5109 - recall: 0.5630 - precision: 0.5120 - f1score: 0.5182
# Epoch 28: val_loss did not improve from 0.69266
# 230/230 [==============================] - 371s 2s/step - loss: 0.6923 - acc: 0.5109 - recall: 0.5630 - precision: 0.5120 - f1score: 0.5182 - val_loss: 0.6933 - val_acc: 0.4467 - val_recall: 0.9196 - val_precision: 0.4949 - val_f1score: 0.6413 - lr: 8.0000e-05
# Epoch 29/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6923 - acc: 0.5141 - recall: 0.5641 - precision: 0.4991 - f1score: 0.5154
# Epoch 29: val_loss did not improve from 0.69266
# 230/230 [==============================] - 370s 2s/step - loss: 0.6923 - acc: 0.5141 - recall: 0.5641 - precision: 0.4991 - f1score: 0.5154 - val_loss: 0.6933 - val_acc: 0.4576 - val_recall: 0.9272 - val_precision: 0.4956 - val_f1score: 0.6439 - lr: 8.0000e-05
# Epoch 30/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6921 - acc: 0.5207 - recall: 0.5717 - precision: 0.5083 - f1score: 0.5242
# Epoch 30: val_loss did not improve from 0.69266
# 230/230 [==============================] - 372s 2s/step - loss: 0.6921 - acc: 0.5207 - recall: 0.5717 - precision: 0.5083 - f1score: 0.5242 - val_loss: 0.6933 - val_acc: 0.4620 - val_recall: 0.9174 - val_precision: 0.4966 - val_f1score: 0.6420 - lr: 8.0000e-05
# Epoch 31/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6920 - acc: 0.5250 - recall: 0.5717 - precision: 0.4964 - f1score: 0.5150
# Epoch 31: val_loss did not improve from 0.69266
# 230/230 [==============================] - 373s 2s/step - loss: 0.6920 - acc: 0.5250 - recall: 0.5717 - precision: 0.4964 - f1score: 0.5150 - val_loss: 0.6933 - val_acc: 0.4446 - val_recall: 0.9109 - val_precision: 0.4922 - val_f1score: 0.6368 - lr: 1.6000e-05
# Epoch 32/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6923 - acc: 0.5022 - recall: 0.5598 - precision: 0.5011 - f1score: 0.5127
# Epoch 32: val_loss did not improve from 0.69266
# 230/230 [==============================] - 370s 2s/step - loss: 0.6923 - acc: 0.5022 - recall: 0.5598 - precision: 0.5011 - f1score: 0.5127 - val_loss: 0.6933 - val_acc: 0.4739 - val_recall: 0.9283 - val_precision: 0.4976 - val_f1score: 0.6458 - lr: 1.6000e-05
# Epoch 33/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6919 - acc: 0.5402 - recall: 0.5783 - precision: 0.5083 - f1score: 0.5270
# Epoch 33: val_loss did not improve from 0.69266
# 230/230 [==============================] - 375s 2s/step - loss: 0.6919 - acc: 0.5402 - recall: 0.5783 - precision: 0.5083 - f1score: 0.5270 - val_loss: 0.6933 - val_acc: 0.4554 - val_recall: 0.9207 - val_precision: 0.4951 - val_f1score: 0.6418 - lr: 1.6000e-05
# Epoch 34/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6918 - acc: 0.5261 - recall: 0.5957 - precision: 0.5132 - f1score: 0.5324
# Epoch 34: val_loss did not improve from 0.69266
# 230/230 [==============================] - 371s 2s/step - loss: 0.6918 - acc: 0.5261 - recall: 0.5957 - precision: 0.5132 - f1score: 0.5324 - val_loss: 0.6933 - val_acc: 0.4663 - val_recall: 0.9391 - val_precision: 0.4997 - val_f1score: 0.6504 - lr: 1.6000e-05
# Epoch 35/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6924 - acc: 0.5130 - recall: 0.5587 - precision: 0.4962 - f1score: 0.5116
# Epoch 35: val_loss did not improve from 0.69266
# 230/230 [==============================] - 372s 2s/step - loss: 0.6924 - acc: 0.5130 - recall: 0.5587 - precision: 0.4962 - f1score: 0.5116 - val_loss: 0.6933 - val_acc: 0.4641 - val_recall: 0.9293 - val_precision: 0.4978 - val_f1score: 0.6462 - lr: 1.6000e-05
# Epoch 36/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6924 - acc: 0.5130 - recall: 0.5620 - precision: 0.4999 - f1score: 0.5133
# Epoch 36: val_loss did not improve from 0.69266
# 230/230 [==============================] - 375s 2s/step - loss: 0.6924 - acc: 0.5130 - recall: 0.5620 - precision: 0.4999 - f1score: 0.5133 - val_loss: 0.6933 - val_acc: 0.4598 - val_recall: 0.9293 - val_precision: 0.4978 - val_f1score: 0.6462 - lr: 3.2000e-06
# Epoch 37/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6922 - acc: 0.5109 - recall: 0.5641 - precision: 0.4914 - f1score: 0.5127
# Epoch 37: val_loss did not improve from 0.69266
# 230/230 [==============================] - 372s 2s/step - loss: 0.6922 - acc: 0.5109 - recall: 0.5641 - precision: 0.4914 - f1score: 0.5127 - val_loss: 0.6933 - val_acc: 0.4641 - val_recall: 0.9293 - val_precision: 0.4978 - val_f1score: 0.6462 - lr: 3.2000e-06
# Epoch 38/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6927 - acc: 0.5033 - recall: 0.5554 - precision: 0.4805 - f1score: 0.4969
# Epoch 38: val_loss did not improve from 0.69266
# 230/230 [==============================] - 375s 2s/step - loss: 0.6927 - acc: 0.5033 - recall: 0.5554 - precision: 0.4805 - f1score: 0.4969 - val_loss: 0.6933 - val_acc: 0.4587 - val_recall: 0.9250 - val_precision: 0.4965 - val_f1score: 0.6440 - lr: 3.2000e-06
# Epoch 39/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6925 - acc: 0.5065 - recall: 0.5674 - precision: 0.4920 - f1score: 0.5132
# Epoch 39: val_loss did not improve from 0.69266
# 230/230 [==============================] - 373s 2s/step - loss: 0.6925 - acc: 0.5065 - recall: 0.5674 - precision: 0.4920 - f1score: 0.5132 - val_loss: 0.6933 - val_acc: 0.4598 - val_recall: 0.9250 - val_precision: 0.4965 - val_f1score: 0.6440 - lr: 3.2000e-06
# Epoch 40/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6920 - acc: 0.5293 - recall: 0.5598 - precision: 0.4969 - f1score: 0.5104
# Epoch 40: val_loss did not improve from 0.69266
# 230/230 [==============================] - 373s 2s/step - loss: 0.6920 - acc: 0.5293 - recall: 0.5598 - precision: 0.4969 - f1score: 0.5104 - val_loss: 0.6933 - val_acc: 0.4413 - val_recall: 0.9250 - val_precision: 0.4968 - val_f1score: 0.6443 - lr: 3.2000e-06
# Epoch 41/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6923 - acc: 0.5337 - recall: 0.5630 - precision: 0.4939 - f1score: 0.5115
# Epoch 41: val_loss did not improve from 0.69266
# 230/230 [==============================] - 371s 2s/step - loss: 0.6923 - acc: 0.5337 - recall: 0.5630 - precision: 0.4939 - f1score: 0.5115 - val_loss: 0.6933 - val_acc: 0.4359 - val_recall: 0.9250 - val_precision: 0.4968 - val_f1score: 0.6443 - lr: 6.4000e-07
# Epoch 42/100
# 230/230 [==============================] - ETA: 0s - loss: 0.6923 - acc: 0.5033 - recall: 0.5739 - precision: 0.4806 - f1score: 0.5104
# Epoch 42: val_loss did not improve from 0.69266
# 230/230 [==============================] - 372s 2s/step - loss: 0.6923 - acc: 0.5033 - recall: 0.5739 - precision: 0.4806 - f1score: 0.5104 - val_loss: 0.6933 - val_acc: 0.4359 - val_recall: 0.9250 - val_precision: 0.4968 - val_f1score: 0.6443 - lr: 6.4000e-07
# Epoch 43/100
#  55/230 [======>.......................] - ETA: 2:23 - loss: 0.6931 - acc: 0.4773 - recall: 0.5773 - precision: 0.4771 - f1score: 0.5067
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-00c84dd234b2> in <module>()
#       4     validation_data=validation_datagen,
#       5     epochs=100, # epochs 복수형으로 쓰기!
# ----> 6     callbacks=[modelcheckpoint, lr_schedule]
#       7 )
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
#history = model.fit(x_train, y_train, validation_split=0.25, epochs=10, verbose=1)
#print(history.history)
#
## 6 훈련 과정 시각화 (정확도)
#plt.plot(history.history['accuracy'])
#plt.plot(history.history['val_accuracy'])
#plt.title('Model accuracy')
#plt.xlabel('Epoch')
#plt.ylabel('Accuracy')
#plt.legend(['Train', 'Test'], loc='upper left')
#plt.show()
#
## 7 훈련 과정 시각화 (손실)
#plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
#plt.title('Model loss')
#plt.xlabel('Epoch')
#plt.ylabel('Loss')
#plt.legend(['Train', 'Test'], loc='upper left')
#plt.show()
