# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import Sequence
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten, Dropout, LSTM, Reshape
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

# %%
import tensorflow as tf
import keras.applications as keras_application

# %%
from keras import backend as K
def recall(y_target, y_pred):
    # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
    # round : 반올림한다
    y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다

    # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 

    # (True Positive + False Negative) = 실제 값이 1(Positive) 전체
    count_true_positive_false_negative = K.sum(y_target_yn)

    # Recall =  (True Positive) / (True Positive + False Negative)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    recall = count_true_positive / (count_true_positive_false_negative + K.epsilon())

    # return a single tensor value
    return recall

def precision(y_target, y_pred):
    # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
    # round : 반올림한다
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다
    y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다

    # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 

    # (True Positive + False Positive) = 예측 값이 1(Positive) 전체
    count_true_positive_false_positive = K.sum(y_pred_yn)

    # Precision = (True Positive) / (True Positive + False Positive)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    precision = count_true_positive / (count_true_positive_false_positive + K.epsilon())

    # return a single tensor value
    return precision

def f1score(y_target, y_pred):
    _recall = recall(y_target, y_pred)
    _precision = precision(y_target, y_pred)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    _f1score = ( 2 * _recall * _precision) / (_recall + _precision+ K.epsilon())
    
    # return a single tensor value
    return _f1score

# %%
from keras.applications import mobilenet_v2

# %%
img_row,img_col=224,224
temp_mobile = mobilenet_v2.MobileNetV2(weights='imagenet', include_top=False, input_shape=(32,img_row*img_col,3), pooling='max')
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
#temp_mobile.summary()

# %%
model=Sequential()

# %%
model.add(temp_mobile)

# %%
#model.add(Dense(32*40, input_shape=(1280,)))

# %%
model.add(Reshape((32,40)))

# %%
model.add(LSTM(32))

# %%
#model.add(Dropout(rate=0.5))

# %%
model.add(Dense(2, activation='sigmoid'))

# %%
model.compile(loss=tf.keras.losses.BinaryCrossentropy(), optimizer=Adam(learning_rate=0.01), metrics=['acc', recall, precision, f1score])
#lr 스케줄링은 나중에model.fit의 callback안에 넣어주자.
#아래와 같이하면됨
#reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
#                              patience=5, min_lr=0.001)
#model.fit(X_train, Y_train, callbacks=[reduce_lr])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 1280)             2257984
#  ional)
#
#  reshape_3 (Reshape)         (None, 32, 40)            0
#
#  lstm_4 (LSTM)               (None, 32)                9344
#
#  dense_3 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 2,267,394
# Trainable params: 2,233,282
# Non-trainable params: 34,112
# _________________________________________________________________

# %%
#model.save('temp_ml5.h5')

# %%
#sample_data
#test = tf.random.uniform([16,32,224*224,3],0,1)
#배치 크기 16쓰자

# %%
import os
cur_path = os.getcwd()
cur_path+='/drive/Shareddrives/capstone_data_process/temp'
video_src = cur_path+'/celeb-df_v2/pre_process/mixed'

# %%
import os
import cv2
cur_path = os.getcwd()
cur_path+='/drive/Shareddrives/capstone_data_process/temp'
all_data = pd.read_csv((cur_path+'/celeb-df_v2/video_data.csv'), names=['file_name', 'label'])
real_num = len(all_data[all_data['label'] == 1])
fake_num = len(all_data[all_data['label'] == 0])
print(real_num, fake_num , real_num+fake_num)
real_alls = all_data[all_data['label'] == 1]
fake_sample = all_data[all_data['label'] == 0].sample(frac=0.11)
all_data_subset = pd.concat([real_alls, fake_sample])
display(all_data_subset)
data_train, data_test = train_test_split(all_data_subset, test_size = 0.2, random_state=2022)
data_train, data_validation = train_test_split(data_train, test_size=0.25, random_state=2022)
print(len(data_train), len(data_validation), len(data_test))
# Out:
# 566 5349 5915
#                file_name  label
# 0           id0_0000.avi      1
# 1           id0_0001.avi      1
# 2           id0_0002.avi      1
# 3           id0_0003.avi      1
# 4           id0_0004.avi      1
# ...                  ...    ...
# 5744  id54_id50_0006.avi      0
# 3356  id30_id35_0005.avi      0
# 4050  id21_id35_0002.avi      0
# 5156   id60_id5_0006.avi      0
# 2184   id23_id6_0001.avi      0
#
# [1154 rows x 2 columns]
# 692 231 231

# %%
test_load = data_train.sample(n=16, replace=True)

# %%
for i in test_load['file_name']:
  print(i)
# Out:
# id20_id16_0003.avi
# id41_id40_0003.avi
# id31_0008.avi
# id21_0000.avi
# id29_0001.avi
# id21_id28_0002.avi
# id16_id0_0013.avi
# id20_id19_0005.avi
# id46_0006.avi
# id37_id9_0007.avi
# id20_id29_0002.avi
# id24_id25_0007.avi
# id57_id52_0008.avi
# id3_id28_0006.avi
# id2_id1_0005.avi
# id7_id13_0005.avi

# %%
#test_video = cv2.VideoCapture(video_src+'/id32_id30_0000.avi')
#result_list = 0
#for i in range(0, 32):
#  if(type(result_list)==type(0)):
#    read_val = cv2.resize(test_video.read()[1], (224, 224))
#    read_val = read_val/255
#    result_list = read_val.reshape(1,224,224,3)
#  else:
#    read_val = cv2.resize(test_video.read()[1], (224, 224))
#    read_val = read_val/255
#    read_val = read_val.reshape(1,224,224,3)
#    result_list = np.concatenate([result_list, read_val])
#result_list=result_list.reshape(32,-1,3)

# %%
#result_list.shape

# %%
#test_load = data_train.sample(n=16, replace=True)
#return_data = 0
#for i in test_load['file_name']:
#  #영상 가져오기
#  test_video = cv2.VideoCapture(video_src+'/'+i)
#  result_list = 0
#  for i in range(0, 32):
#    if(type(result_list)==type(0)):
#      read_val = cv2.resize(test_video.read()[1], (224, 224))
#      read_val = read_val/255
#      result_list = read_val.reshape(1,224,224,3)
#    else:
#      read_val = cv2.resize(test_video.read()[1], (224, 224))
#      read_val = read_val/255
#      read_val = read_val.reshape(1,224,224,3)
#      result_list = np.concatenate([result_list, read_val])
#  result_list=result_list.reshape(32,-1,3)
#  #영상 가져오기 끝
#  if(type(return_data)==type(0)):
#    return_data = result_list.reshape(1, 32, -1, 3)
#  else:
#    return_data = np.concatenate([return_data, result_list.reshape(1, 32, -1, 3)])
#return_label = []
#for i in test_load['label']:
#  if(i==0):
#    target = np.array([1,0])
#  else:
#    target = np.array([0,1])
#  return_label.append(target)
#return_label = np.stack(return_label)

# %%
#return_label

# %%
#return_data.shape

# %%
#len(data_train)

# %%
class DataGenerator(Sequence):
    def __init__(self, dataset, batch_size):
      self.dataset = dataset
      self.batch_size = batch_size

    def __len__(self):
      return int(len(data_train) / self.batch_size)

    def __getitem__(self, index):
      test_load = self.dataset.sample(n=self.batch_size, replace=True, random_state=index)
      return_data = 0
      for i in test_load['file_name']:
        #영상 가져오기
        test_video = cv2.VideoCapture(video_src+'/'+i)
        result_list = 0
        for i in range(0, 32):
          if(type(result_list)==type(0)):
            read_val = cv2.resize(test_video.read()[1], (224, 224))
            read_val = read_val/255
            result_list = read_val.reshape(1,224,224,3)
          else:
            read_val = cv2.resize(test_video.read()[1], (224, 224))
            read_val = read_val/255
            read_val = read_val.reshape(1,224,224,3)
            result_list = np.concatenate([result_list, read_val])
        result_list=result_list.reshape(32,-1,3)
        #영상 가져오기 끝
        if(type(return_data)==type(0)):
          return_data = result_list.reshape(1, 32, -1, 3)
        else:
          return_data = np.concatenate([return_data, result_list.reshape(1, 32, -1, 3)])
      return_label = []
      for i in test_load['label']:
        if(i==0):
          target = np.array([1,0])
        else:
          target = np.array([0,1])
        return_label.append(target)
      return_label = np.stack(return_label)
      return return_data, return_label

# %%
train_datagen = DataGenerator(data_train, 2)

# %%
validation_datagen = DataGenerator(data_validation, 2)

# %%
result = train_datagen.__getitem__(0)

# %%
result[1].shape
# Out:
# (2, 2)

# %%
#저장경로
store_tensor_model_path = cur_path+'/trained_models/tensorflow'

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# %%
#callback 학습 시 활용할 함수들
#모델의 weight와 모델의 network구조를 저장함 //verbose=1: 저장했다고 출력해라 // save_best_only=True: 가장좋은거 하나 저장한다
modelcheckpoint=ModelCheckpoint(store_tensor_model_path+'/first_try.h5', monitor='val_loss', verbose=1, save_best_only=True)
#lr스케줄링
lr_schedule = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.0000001)

# %%
#모델을 저장했다가, 나중에 사용할 수 있도록 callback을 사용함, 저장은 로컬에 저장이됨_ 옆에 파일있는곳에 보임
history = model.fit(
    train_datagen,
    validation_data=validation_datagen, 
    epochs=100, # epochs 복수형으로 쓰기!
    callbacks=[modelcheckpoint, lr_schedule]
)
# Out:
# Epoch 1/100
# 346/346 [==============================] - ETA: 0s - loss: 0.7062 - acc: 0.5043 - recall: 0.4957 - precision: 0.4860 - f1score: 0.4872
# Epoch 1: val_loss improved from inf to 0.69095, saving model to /content/drive/Shareddrives/capstone_data_process/temp/trained_models/tensorflow/first_try.h5
# 346/346 [==============================] - 448s 1s/step - loss: 0.7062 - acc: 0.5043 - recall: 0.4957 - precision: 0.4860 - f1score: 0.4872 - val_loss: 0.6909 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 0.0100
# Epoch 2/100
# 346/346 [==============================] - ETA: 0s - loss: 0.7029 - acc: 0.4798 - recall: 0.4812 - precision: 0.4812 - f1score: 0.4803
# Epoch 2: val_loss improved from 0.69095 to 0.69013, saving model to /content/drive/Shareddrives/capstone_data_process/temp/trained_models/tensorflow/first_try.h5
# 346/346 [==============================] - 329s 952ms/step - loss: 0.7029 - acc: 0.4798 - recall: 0.4812 - precision: 0.4812 - f1score: 0.4803 - val_loss: 0.6901 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 0.0100
# Epoch 3/100
# 346/346 [==============================] - ETA: 0s - loss: 0.7013 - acc: 0.5072 - recall: 0.5072 - precision: 0.5072 - f1score: 0.5072
# Epoch 3: val_loss improved from 0.69013 to 0.68951, saving model to /content/drive/Shareddrives/capstone_data_process/temp/trained_models/tensorflow/first_try.h5
# 346/346 [==============================] - 330s 953ms/step - loss: 0.7013 - acc: 0.5072 - recall: 0.5072 - precision: 0.5072 - f1score: 0.5072 - val_loss: 0.6895 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 0.0100
# Epoch 4/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6963 - acc: 0.5101 - recall: 0.5087 - precision: 0.5087 - f1score: 0.5087
# Epoch 4: val_loss did not improve from 0.68951
# 346/346 [==============================] - 328s 948ms/step - loss: 0.6963 - acc: 0.5101 - recall: 0.5087 - precision: 0.5087 - f1score: 0.5087 - val_loss: 0.7035 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 0.0100
# Epoch 5/100
# 346/346 [==============================] - ETA: 0s - loss: 0.7025 - acc: 0.4928 - recall: 0.4913 - precision: 0.4913 - f1score: 0.4913
# Epoch 5: val_loss did not improve from 0.68951
# 346/346 [==============================] - 327s 946ms/step - loss: 0.7025 - acc: 0.4928 - recall: 0.4913 - precision: 0.4913 - f1score: 0.4913 - val_loss: 0.7009 - val_acc: 0.4552 - val_recall: 0.4552 - val_precision: 0.4552 - val_f1score: 0.4552 - lr: 0.0100
# Epoch 6/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6978 - acc: 0.4957 - recall: 0.4957 - precision: 0.4957 - f1score: 0.4957
# Epoch 6: val_loss did not improve from 0.68951
# 346/346 [==============================] - 327s 945ms/step - loss: 0.6978 - acc: 0.4957 - recall: 0.4957 - precision: 0.4957 - f1score: 0.4957 - val_loss: 0.6896 - val_acc: 0.5448 - val_recall: 0.5491 - val_precision: 0.5472 - val_f1score: 0.5480 - lr: 0.0100
# Epoch 7/100
# 346/346 [==============================] - ETA: 0s - loss: 0.7001 - acc: 0.4870 - recall: 0.4870 - precision: 0.4870 - f1score: 0.4870
# Epoch 7: val_loss did not improve from 0.68951
# 346/346 [==============================] - 328s 947ms/step - loss: 0.7001 - acc: 0.4870 - recall: 0.4870 - precision: 0.4870 - f1score: 0.4870 - val_loss: 0.6907 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 0.0100
# Epoch 8/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6985 - acc: 0.4754 - recall: 0.4754 - precision: 0.4754 - f1score: 0.4754
# Epoch 8: val_loss did not improve from 0.68951
# 346/346 [==============================] - 327s 945ms/step - loss: 0.6985 - acc: 0.4754 - recall: 0.4754 - precision: 0.4754 - f1score: 0.4754 - val_loss: 0.6947 - val_acc: 0.4552 - val_recall: 0.4552 - val_precision: 0.4552 - val_f1score: 0.4552 - lr: 0.0100
# Epoch 9/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6934 - acc: 0.5043 - recall: 0.5043 - precision: 0.5043 - f1score: 0.5043
# Epoch 9: val_loss did not improve from 0.68951
# 346/346 [==============================] - 327s 944ms/step - loss: 0.6934 - acc: 0.5043 - recall: 0.5043 - precision: 0.5043 - f1score: 0.5043 - val_loss: 0.6904 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 1.0000e-03
# Epoch 10/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6937 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130
# Epoch 10: val_loss did not improve from 0.68951
# 346/346 [==============================] - 326s 941ms/step - loss: 0.6937 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130 - val_loss: 0.6911 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 1.0000e-03
# Epoch 11/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6936 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130
# Epoch 11: val_loss did not improve from 0.68951
# 346/346 [==============================] - 328s 949ms/step - loss: 0.6936 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130 - val_loss: 0.6919 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 1.0000e-03
# Epoch 12/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6934 - acc: 0.5014 - recall: 0.5014 - precision: 0.5014 - f1score: 0.5014
# Epoch 12: val_loss did not improve from 0.68951
# 346/346 [==============================] - 321s 929ms/step - loss: 0.6934 - acc: 0.5014 - recall: 0.5014 - precision: 0.5014 - f1score: 0.5014 - val_loss: 0.6908 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 1.0000e-03
# Epoch 13/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6937 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130
# Epoch 13: val_loss did not improve from 0.68951
# 346/346 [==============================] - 318s 918ms/step - loss: 0.6937 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130 - val_loss: 0.6904 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 1.0000e-03
# Epoch 14/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6929 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130
# Epoch 14: val_loss did not improve from 0.68951
# 346/346 [==============================] - 320s 923ms/step - loss: 0.6929 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130 - val_loss: 0.6905 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 1.0000e-04
# Epoch 15/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6929 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130
# Epoch 15: val_loss did not improve from 0.68951
# 346/346 [==============================] - 318s 920ms/step - loss: 0.6929 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130 - val_loss: 0.6906 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 1.0000e-04
# Epoch 16/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6930 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130
# Epoch 16: val_loss did not improve from 0.68951
# 346/346 [==============================] - 316s 914ms/step - loss: 0.6930 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130 - val_loss: 0.6907 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 1.0000e-04
# Epoch 17/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6929 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130
# Epoch 17: val_loss did not improve from 0.68951
# 346/346 [==============================] - 322s 930ms/step - loss: 0.6929 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130 - val_loss: 0.6907 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 1.0000e-04
# Epoch 18/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6929 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130
# Epoch 18: val_loss did not improve from 0.68951
# 346/346 [==============================] - 324s 938ms/step - loss: 0.6929 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130 - val_loss: 0.6908 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 1.0000e-04
# Epoch 19/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6928 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130
# Epoch 19: val_loss did not improve from 0.68951
# 346/346 [==============================] - 327s 944ms/step - loss: 0.6928 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130 - val_loss: 0.6908 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 1.0000e-05
# Epoch 20/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6928 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130
# Epoch 20: val_loss did not improve from 0.68951
# 346/346 [==============================] - 325s 940ms/step - loss: 0.6928 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130 - val_loss: 0.6908 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 1.0000e-05
# Epoch 21/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6928 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130
# Epoch 21: val_loss did not improve from 0.68951
# 346/346 [==============================] - 325s 940ms/step - loss: 0.6928 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130 - val_loss: 0.6908 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 1.0000e-05
# Epoch 22/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6928 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130
# Epoch 22: val_loss did not improve from 0.68951
# 346/346 [==============================] - 328s 947ms/step - loss: 0.6928 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130 - val_loss: 0.6908 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 1.0000e-05
# Epoch 23/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6928 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130
# Epoch 23: val_loss did not improve from 0.68951
# 346/346 [==============================] - 330s 953ms/step - loss: 0.6928 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130 - val_loss: 0.6908 - val_acc: 0.5448 - val_recall: 0.5448 - val_precision: 0.5448 - val_f1score: 0.5448 - lr: 1.0000e-05
# Epoch 24/100
# 346/346 [==============================] - ETA: 0s - loss: 0.6928 - acc: 0.5130 - recall: 0.5130 - precision: 0.5130 - f1score: 0.5130
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-90-00c84dd234b2> in <module>()
#       4     validation_data=validation_datagen,
#       5     epochs=100, # epochs 복수형으로 쓰기!
# ----> 6     callbacks=[modelcheckpoint, lr_schedule]
#       7 )
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1429               use_multiprocessing=use_multiprocessing,
#    1430               return_dict=True,
# -> 1431               _use_cached_eval_dataset=True)
#    1432           val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1433           epoch_logs.update(val_logs)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1714             with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    1715               callbacks.on_test_batch_begin(step)
# -> 1716               tmp_logs = self.test_function(iterator)
#    1717               if data_handler.should_sync:
#    1718                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     952       # In this case we have not created variables on the first call. So we can
#     953       # run the first trace but we should fail if variables are created.
# --> 954       results = self._stateful_fn(*args, **kwds)
#     955       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
#history = model.fit(x_train, y_train, validation_split=0.25, epochs=10, verbose=1)
#print(history.history)
#
## 6 훈련 과정 시각화 (정확도)
#plt.plot(history.history['accuracy'])
#plt.plot(history.history['val_accuracy'])
#plt.title('Model accuracy')
#plt.xlabel('Epoch')
#plt.ylabel('Accuracy')
#plt.legend(['Train', 'Test'], loc='upper left')
#plt.show()
#
## 7 훈련 과정 시각화 (손실)
#plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
#plt.title('Model loss')
#plt.xlabel('Epoch')
#plt.ylabel('Loss')
#plt.legend(['Train', 'Test'], loc='upper left')
#plt.show()
